# %% [markdown]
# Im about to write my first jupyter notebook

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(5)
# Out:
# 5

# %%
print(1+1)
# Out:
# 2

# %%
five = 5
one = 1
twodot = 2.0
print (five)
print (one + one)
message = "This is a string"
print (message)
# Out:
# 5
# 2
# This is a string

# %%
integer_variable = 100
floating_point_variable = 100.0
string_variable = "Name"

# %%
print (type(integer_variable))
# Out:
# <class 'int'>

# %%
print (5/2)
print (5.0/2)
print ("Hello" + " World")
##print ("some" + 1)
##print ("number" * 5)
print (3+5*2)
# Out:
# 2.5
# 2.5
# Hello World
# 13

# %%
numIn = input("please enter a number: ")
# Out:
# please enter a number: 4.667778

# %%
StringIn = input("please enter a string: ")
# Out:
# please enter a string: Hello

# %%
print ("the number that you wrote was : ", numIn)
print ("The number that you wrote was : ", StringIn)
# Out:
# the number that you wrote was :  4.667778
# The number that you wrote was :  Hello

# %%
my_file = open("output_file.txt", 'w')
var1 = "This is a string\n"
my_file.write(var1)
var2 = 10
my_file.write("\n")
my_file.write(str(var2))
var3 = 20.0
my_file.write("\n")
my_file.write(str(var3))
my_file.close()

# %%
my_file = open("output_file.txt", 'r')
content = my_file.read()
print(content)
my_file.close()
# Out:
# This is a string
#
# 10
# 20.0
