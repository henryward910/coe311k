# %% [markdown]
# Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Setting Range 10 to 1000 with steps of 20

# %%
N_vals = np.arange(10, 1001, 20)

# %% [markdown]
# MC function

# %%
def MC_pi(N_vals):
    diff = []

    for N in N_vals:
        x = np.random.uniform(-1, 1 , N)
        y = np.random.uniform(-1, 1 , N)

        N_hits = np.sum(x*x + y*y < 1)

        pi_mc = 4 * N_hits / N       
        diff.append(abs(pi_mc - np.pi))

    return np.array(diff)

# %% [markdown]
# Calling MC function

# %%
diff = MC_pi(N_vals)

# %% [markdown]
# Plot Routine

# %%
plt.figure(figsize=(12, 4))
plt.plot(N_vals, diff)
plt.xlabel('Number of Samples')
plt.ylabel('Variation from Pi')
plt.title("Monte Carlo Pi Approximation ")
plt.show()
