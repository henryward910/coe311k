# %%
base10 = 2025

# %%
def base2(base10):
    conversion = ""
    while base10 > 0:  
        conversion = str(base10 % 2) + conversion
        base10//=2
    return conversion

# %%
print(base2(base10))
# Out:
# 11111101001
